# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)

# Add the lats and lngs into a list
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
import sys
# Calling the API and Parsing JSON Data
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through alll the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    
    # create end point url
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers an d the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count 
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
        # If an error is experienced skip the city
    except:
        print("City not found, skipping...")
        print(sys.exc_info())
        pass
        
# indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tanshui
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E749748>)
# Processing Record 2 of Set 1 | skjervoy
# {'coord': {'lon': 20.9714, 'lat': 70.0311}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 29.52, 'feels_like': 23.97, 'temp_min': 29.52, 'temp_max': 29.52, 'pressure': 1027, 'humidity': 67, 'sea_level': 1027, 'grnd_level': 1027}, 'visibility': 10000, 'wind': {'speed': 5.19, 'deg': 111, 'gust': 5.32}, 'snow': {'1h': 0.11}, 'clouds': {'all': 100}, 'dt': 1639963711, 'sys': {'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 777682, 'name': 'Skjervøy', 'cod': 200}
# Processing Record 3 of Set 1 | ancud
# {'coord': {'lon': -73.8203, 'lat': -41.8697}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 62.13, 'feels_like': 62.22, 'temp_min': 60.42, 'temp_max': 62.13, 'pressure': 1018, 'humidity': 89, 'sea_level': 1018, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.95, 'deg': 241, 'gust': 7.4}, 'clouds': {'all': 21}, 'dt': 1639963117, 'sys': {'type': 1, 'id': 8512, 'country': 'CL', 'sunrise': 1639905351, 'sunset': 1639960152}, 'timezone': -10800, 'id': 3899695, 'name': 'Ancud', 'cod': 200}
# Processing Record 4 of Set 1 | tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -14.8, 'feels_like': -27.4, 'temp_min': -14.8, 'temp_max': -14.8, 'pressure': 1024, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 100}, 'clouds': {'all': 90}, 'dt': 1639963712, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 0, 'sunset': 0}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 5 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E7B30C8>)
# Processing Record 6 of Set 1 | carutapera
# {'coord': {'lon': -46.02, 'lat': -1.195}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.27, 'feels_like': 79.27, 'temp_min': 79.27, 'temp_max': 79.27, 'pressure': 1010, 'humidity': 81, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 78, 'gust': 14.65}, 'clouds': {'all': 100}, 'dt': 1639963205, 'sys': {'country': 'BR', 'sunrise': 1639904136, 'sunset': 1639948019}, 'timezone': -10800, 'id': 3402648, 'name': 'Carutapera', 'cod': 200}
# Processing Record 7 of Set 1 | vila franca do campo
# {'coord': {'lon': -25.4333, 'lat': 37.7167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 58.19, 'feels_like': 57.61, 'temp_min': 58.19, 'temp_max': 59.41, 'pressure': 993, 'humidity': 83, 'sea_level': 993, 'grnd_level': 990}, 'visibility': 10000, 'wind': {'speed': 9.71, 'deg': 249, 'gust': 14.25}, 'clouds': {'all': 100}, 'dt': 1639963712, 'sys': {'type': 2, 'id': 37781, 'country': 'PT', 'sunrise': 1639990373, 'sunset': 1640024754}, 'timezone': -3600, 'id': 3372472, 'name': 'Vila Franca do Campo', 'cod': 200}
# Processing Record 8 of Set 1 | hithadhoo
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.6, 'feels_like': 88.61, 'temp_min': 82.6, 'temp_max': 82.6, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.36, 'deg': 187, 'gust': 7.45}, 'clouds': {'all': 100}, 'dt': 1639963713, 'sys': {'country': 'MV', 'sunrise': 1639962032, 'sunset': 1640005791}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 9 of Set 1 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E7B3108>)
# Processing Record 10 of Set 1 | alofi
# {'coord': {'lon': -169.9187, 'lat': -19.0595}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.09, 'feels_like': 87.94, 'temp_min': 84.09, 'temp_max': 84.09, 'pressure': 1014, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 120}, 'clouds': {'all': 18}, 'dt': 1639963713, 'sys': {'type': 1, 'id': 7306, 'country': 'NU', 'sunrise': 1639931924, 'sunset': 1639979722}, 'timezone': -39600, 'id': 4036284, 'name': 'Alofi', 'cod': 200}
# Processing Record 11 of Set 1 | valle de allende
# {'coord': {'lon': -105.4, 'lat': 26.9333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 49.48, 'feels_like': 45.95, 'temp_min': 49.48, 'temp_max': 49.48, 'pressure': 1018, 'humidity': 69, 'sea_level': 1018, 'grnd_level': 843}, 'visibility': 10000, 'wind': {'speed': 8.46, 'deg': 19, 'gust': 13.53}, 'clouds': {'all': 5}, 'dt': 1639963713, 'sys': {'country': 'MX', 'sunrise': 1639921535, 'sunset': 1639959131}, 'timezone': -25200, 'id': 3980627, 'name': 'Valle de Allende', 'cod': 200}
# Processing Record 12 of Set 1 | cabo san lucas
# {'coord': {'lon': -109.9124, 'lat': 22.8909}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 70.63, 'feels_like': 70.83, 'temp_min': 68.18, 'temp_max': 74.14, 'pressure': 1017, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 140}, 'clouds': {'all': 40}, 'dt': 1639963436, 'sys': {'type': 1, 'id': 7151, 'country': 'MX', 'sunrise': 1639922107, 'sunset': 1639960727}, 'timezone': -25200, 'id': 3985710, 'name': 'Cabo San Lucas', 'cod': 200}
# Processing Record 13 of Set 1 | saldanha
# {'coord': {'lon': 17.9442, 'lat': -33.0117}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.85, 'feels_like': 60.26, 'temp_min': 60.85, 'temp_max': 60.85, 'pressure': 1010, 'humidity': 77, 'sea_level': 1010, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 4.68, 'deg': 341, 'gust': 6.17}, 'clouds': {'all': 85}, 'dt': 1639963714, 'sys': {'type': 1, 'id': 1943, 'country': 'ZA', 'sunrise': 1639971354, 'sunset': 1640022945}, 'timezone': 7200, 'id': 3361934, 'name': 'Saldanha', 'cod': 200}
# Processing Record 14 of Set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 24.46, 'feels_like': 24.46, 'temp_min': 20.08, 'temp_max': 26.29, 'pressure': 1025, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 183, 'gust': 1.99}, 'clouds': {'all': 46}, 'dt': 1639963714, 'sys': {'type': 2, 'id': 2008828, 'country': 'US', 'sunrise': 1639917664, 'sunset': 1639950439}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 15 of Set 1 | lompoc
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 50.83, 'feels_like': 49.42, 'temp_min': 47.43, 'temp_max': 55.54, 'pressure': 1018, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 264}, 'clouds': {'all': 20}, 'dt': 1639963708, 'sys': {'type': 2, 'id': 2005037, 'country': 'US', 'sunrise': 1639926252, 'sunset': 1639961645}, 'timezone': -28800, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# Processing Record 16 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.45, 'feels_like': 88.3, 'temp_min': 82.45, 'temp_max': 82.45, 'pressure': 1009, 'humidity': 74, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 15.77, 'deg': 118, 'gust': 16.2}, 'clouds': {'all': 99}, 'dt': 1639963714, 'sys': {'country': 'KI', 'sunrise': 1639938476, 'sunset': 1639981472}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 17 of Set 1 | roma
# {'coord': {'lon': -75.4557, 'lat': 43.2128}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 20.41, 'feels_like': 20.41, 'temp_min': 16.39, 'temp_max': 26.46, 'pressure': 1026, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1639963715, 'sys': {'type': 2, 'id': 2007612, 'country': 'US', 'sunrise': 1639916983, 'sunset': 1639949306}, 'timezone': -18000, 'id': 5134295, 'name': 'Rome', 'cod': 200}
# Processing Record 18 of Set 1 | dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -29.58, 'feels_like': -29.58, 'temp_min': -29.58, 'temp_max': -29.58, 'pressure': 1034, 'humidity': 99, 'sea_level': 1034, 'grnd_level': 1028}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 174, 'gust': 2.73}, 'clouds': {'all': 85}, 'dt': 1639963715, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 19 of Set 1 | norman wells
# {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 1.44, 'feels_like': -8.23, 'temp_min': 1.44, 'temp_max': 1.44, 'pressure': 1025, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 100}, 'snow': {'1h': 0.24}, 'clouds': {'all': 90}, 'dt': 1639963417, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1639939382, 'sunset': 1639951575}, 'timezone': -25200, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# Processing Record 20 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 73.47, 'feels_like': 72.68, 'temp_min': 73.47, 'temp_max': 73.47, 'pressure': 993, 'humidity': 46, 'sea_level': 993, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 13.96, 'deg': 317, 'gust': 48.25}, 'rain': {'1h': 0.3}, 'clouds': {'all': 97}, 'dt': 1639963716, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1639932518, 'sunset': 1639989315}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 21 of Set 1 | luwuk
# {'coord': {'lon': 122.7875, 'lat': -0.9516}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.51, 'feels_like': 93.9, 'temp_min': 85.51, 'temp_max': 85.51, 'pressure': 1012, 'humidity': 70, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 1.05, 'deg': 56, 'gust': 5.17}, 'clouds': {'all': 98}, 'dt': 1639963716, 'sys': {'country': 'ID', 'sunrise': 1639950063, 'sunset': 1639993895}, 'timezone': 28800, 'id': 1637001, 'name': 'Luwuk', 'cod': 200}
# Processing Record 22 of Set 1 | sept-iles
# {'coord': {'lon': -66.3821, 'lat': 50.2001}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 13.98, 'feels_like': 13.98, 'temp_min': 7.32, 'temp_max': 14.05, 'pressure': 1018, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 19, 'gust': 5.01}, 'clouds': {'all': 75}, 'dt': 1639963510, 'sys': {'type': 2, 'id': 2006302, 'country': 'CA', 'sunrise': 1639916490, 'sunset': 1639945442}, 'timezone': -18000, 'id': 6144312, 'name': 'Sept-Îles', 'cod': 200}
# Processing Record 23 of Set 1 | nyurba
# {'coord': {'lon': 118.3319, 'lat': 63.2842}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -29.58, 'feels_like': -42.18, 'temp_min': -29.58, 'temp_max': -29.58, 'pressure': 1021, 'humidity': 96, 'sea_level': 1021, 'grnd_level': 1005}, 'visibility': 7713, 'wind': {'speed': 7.05, 'deg': 245, 'gust': 16.4}, 'clouds': {'all': 100}, 'dt': 1639963716, 'sys': {'country': 'RU', 'sunrise': 1639964810, 'sunset': 1639981287}, 'timezone': 32400, 'id': 2018735, 'name': 'Nyurba', 'cod': 200}
# Processing Record 24 of Set 1 | nanortalik
# {'coord': {'lon': -45.2371, 'lat': 60.1432}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 40.05, 'feels_like': 28.99, 'temp_min': 40.05, 'temp_max': 40.05, 'pressure': 1006, 'humidity': 70, 'sea_level': 1006, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 27.36, 'deg': 76, 'gust': 40.51}, 'clouds': {'all': 100}, 'dt': 1639963497, 'sys': {'country': 'GL', 'sunrise': 1639915399, 'sunset': 1639936380}, 'timezone': -10800, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# Processing Record 25 of Set 1 | ocos
# {'coord': {'lon': -92.1933, 'lat': 14.5094}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 79.2, 'feels_like': 79.2, 'temp_min': 78.98, 'temp_max': 83.32, 'pressure': 1011, 'humidity': 76, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 9.08, 'deg': 295, 'gust': 10.58}, 'clouds': {'all': 0}, 'dt': 1639963717, 'sys': {'type': 1, 'id': 7171, 'country': 'GT', 'sunrise': 1639916882, 'sunset': 1639957443}, 'timezone': -21600, 'id': 3592086, 'name': 'Ocós', 'cod': 200}
# Processing Record 26 of Set 1 | leningradskiy
# {'coord': {'lon': 178.4167, 'lat': 69.3833}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 0.99, 'feels_like': -11.61, 'temp_min': 0.99, 'temp_max': 0.99, 'pressure': 981, 'humidity': 93, 'sea_level': 981, 'grnd_level': 981}, 'visibility': 3305, 'wind': {'speed': 6.93, 'deg': 289, 'gust': 14.76}, 'snow': {'1h': 0.1}, 'clouds': {'all': 100}, 'dt': 1639963429, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# Processing Record 27 of Set 1 | thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -7.44, 'feels_like': -20.04, 'temp_min': -7.44, 'temp_max': -7.44, 'pressure': 1006, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1639963717, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1639925909, 'sunset': 1639951135}, 'timezone': -21600, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# Processing Record 28 of Set 1 | havre-saint-pierre
# {'coord': {'lon': -63.5986, 'lat': 50.2334}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 14.54, 'feels_like': 14.54, 'temp_min': 14.36, 'temp_max': 18.19, 'pressure': 1017, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 340}, 'clouds': {'all': 90}, 'dt': 1639963565, 'sys': {'type': 1, 'id': 812, 'country': 'CA', 'sunrise': 1639915831, 'sunset': 1639944764}, 'timezone': -18000, 'id': 5972291, 'name': 'Havre-St-Pierre', 'cod': 200}
# Processing Record 29 of Set 1 | ballina
# {'coord': {'lon': 153.5667, 'lat': -28.8667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 90.05, 'temp_min': 84.94, 'temp_max': 89.78, 'pressure': 1013, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 240}, 'clouds': {'all': 96}, 'dt': 1639963719, 'sys': {'type': 1, 'id': 9496, 'country': 'AU', 'sunrise': 1639939417, 'sunset': 1639989762}, 'timezone': 39600, 'id': 2177069, 'name': 'Ballina', 'cod': 200}
# Processing Record 30 of Set 1 | saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -9.18, 'feels_like': -21.78, 'temp_min': -9.18, 'temp_max': -9.18, 'pressure': 1022, 'humidity': 98, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 433, 'wind': {'speed': 10.4, 'deg': 303, 'gust': 19.89}, 'clouds': {'all': 100}, 'dt': 1639963720, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 31 of Set 1 | maniitsoq
# {'coord': {'lon': -52.9, 'lat': 65.4167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 38.71, 'feels_like': 27.9, 'temp_min': 38.71, 'temp_max': 38.71, 'pressure': 1009, 'humidity': 59, 'sea_level': 1009, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 23.89, 'deg': 76, 'gust': 31.7}, 'clouds': {'all': 100}, 'dt': 1639963226, 'sys': {'country': 'GL', 'sunrise': 1639921811, 'sunset': 1639933647}, 'timezone': -10800, 'id': 3421982, 'name': 'Maniitsoq', 'cod': 200}
# Processing Record 32 of Set 1 | kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 76.28, 'feels_like': 77.09, 'temp_min': 74.19, 'temp_max': 80.58, 'pressure': 1017, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 266, 'gust': 13}, 'rain': {'1h': 0.64}, 'clouds': {'all': 40}, 'dt': 1639963720, 'sys': {'type': 2, 'id': 2001562, 'country': 'US', 'sunrise': 1639933869, 'sunset': 1639972687}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 33 of Set 1 | cayenne
# {'coord': {'lon': -52.3333, 'lat': 4.9333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 81.09, 'feels_like': 87.24, 'temp_min': 77.04, 'temp_max': 81.09, 'pressure': 1010, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 61, 'gust': 8.99}, 'clouds': {'all': 0}, 'dt': 1639963161, 'sys': {'type': 2, 'id': 2038747, 'country': 'GF', 'sunrise': 1639906289, 'sunset': 1639948897}, 'timezone': -10800, 'id': 3382160, 'name': 'Cayenne', 'cod': 200}
# Processing Record 34 of Set 1 | beira
# {'coord': {'lon': 34.8389, 'lat': -19.8436}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.25, 'feels_like': 76.15, 'temp_min': 75.25, 'temp_max': 75.25, 'pressure': 1014, 'humidity': 78, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 8.23, 'deg': 177, 'gust': 13.85}, 'clouds': {'all': 70}, 'dt': 1639963720, 'sys': {'country': 'MZ', 'sunrise': 1639969100, 'sunset': 1640017087}, 'timezone': 7200, 'id': 1052373, 'name': 'Beira', 'cod': 200}
# Processing Record 35 of Set 1 | liku
# {'coord': {'lon': 119.8922, 'lat': -0.7275}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.81, 'feels_like': 89.94, 'temp_min': 82.81, 'temp_max': 82.81, 'pressure': 1013, 'humidity': 77, 'sea_level': 1013, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 1.28, 'deg': 98, 'gust': 1.7}, 'clouds': {'all': 97}, 'dt': 1639963721, 'sys': {'country': 'ID', 'sunrise': 1639950781, 'sunset': 1639994567}, 'timezone': 28800, 'id': 1633034, 'name': 'Liku', 'cod': 200}
# Processing Record 36 of Set 1 | blora
# {'coord': {'lon': 111.4186, 'lat': -6.9698}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.21, 'feels_like': 77.85, 'temp_min': 76.21, 'temp_max': 76.21, 'pressure': 1013, 'humidity': 92, 'sea_level': 1013, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 5.19, 'deg': 184, 'gust': 8.37}, 'clouds': {'all': 100}, 'dt': 1639963721, 'sys': {'country': 'ID', 'sunrise': 1639952160, 'sunset': 1639997256}, 'timezone': 25200, 'id': 1648568, 'name': 'Blora', 'cod': 200}
# Processing Record 37 of Set 1 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 21.65, 'feels_like': 9.27, 'temp_min': 18.14, 'temp_max': 25.27, 'pressure': 1022, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 13, 'deg': 275, 'gust': 24}, 'clouds': {'all': 10}, 'dt': 1639963722, 'sys': {'type': 2, 'id': 19530, 'country': 'US', 'sunrise': 1639916500, 'sunset': 1639949073}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 38 of Set 1 | mildura
# {'coord': {'lon': 142.15, 'lat': -34.2}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.56, 'feels_like': 69.64, 'temp_min': 71.56, 'temp_max': 72.07, 'pressure': 1018, 'humidity': 26}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 210}, 'clouds': {'all': 5}, 'dt': 1639963647, 'sys': {'type': 1, 'id': 9550, 'country': 'AU', 'sunrise': 1639941345, 'sunset': 1639993316}, 'timezone': 39600, 'id': 2157698, 'name': 'Mildura', 'cod': 200}
# Processing Record 39 of Set 1 | fort nelson
# {'coord': {'lon': -122.7002, 'lat': 58.8053}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 4.77, 'feels_like': 4.77, 'temp_min': 4.77, 'temp_max': 4.77, 'pressure': 1027, 'humidity': 96, 'sea_level': 1027, 'grnd_level': 973}, 'visibility': 331, 'wind': {'speed': 0.72, 'deg': 353, 'gust': 3.18}, 'snow': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1639963722, 'sys': {'country': 'CA', 'sunrise': 1639933263, 'sunset': 1639955711}, 'timezone': -25200, 'id': 5955902, 'name': 'Fort Nelson', 'cod': 200}
# Processing Record 40 of Set 1 | ponta do sol
# {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.94, 'feels_like': 67.69, 'temp_min': 65.12, 'temp_max': 69.01, 'pressure': 1011, 'humidity': 93, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 3300, 'wind': {'speed': 20.42, 'deg': 216, 'gust': 30.13}, 'clouds': {'all': 100}, 'dt': 1639963435, 'sys': {'type': 2, 'id': 2008291, 'country': 'PT', 'sunrise': 1639987567, 'sunset': 1640023559}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# Processing Record 41 of Set 1 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -11.4, 'feels_like': -24, 'temp_min': -11.4, 'temp_max': -11.4, 'pressure': 1028, 'humidity': 97, 'sea_level': 1028, 'grnd_level': 1024}, 'visibility': 760, 'wind': {'speed': 11.68, 'deg': 236, 'gust': 17.36}, 'clouds': {'all': 100}, 'dt': 1639963722, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 42 of Set 1 | plettenberg bay
# {'coord': {'lon': 23.3716, 'lat': -34.0527}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.06, 'feels_like': 64.58, 'temp_min': 64.06, 'temp_max': 64.06, 'pressure': 1015, 'humidity': 94, 'sea_level': 1015, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 6.53, 'deg': 100, 'gust': 9.24}, 'clouds': {'all': 100}, 'dt': 1639963723, 'sys': {'country': 'ZA', 'sunrise': 1639969884, 'sunset': 1640021809}, 'timezone': 7200, 'id': 964712, 'name': 'Plettenberg Bay', 'cod': 200}
# Processing Record 43 of Set 1 | waynesboro
# {'coord': {'lon': -78.8895, 'lat': 38.0685}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 31.64, 'feels_like': 27.03, 'temp_min': 29.03, 'temp_max': 34.99, 'pressure': 1025, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 20}, 'clouds': {'all': 1}, 'dt': 1639963689, 'sys': {'type': 1, 'id': 6231, 'country': 'US', 'sunrise': 1639916836, 'sunset': 1639951101}, 'timezone': -18000, 'id': 4792522, 'name': 'Waynesboro', 'cod': 200}
# Processing Record 44 of Set 1 | chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -3.87, 'feels_like': -16.47, 'temp_min': -3.87, 'temp_max': -3.87, 'pressure': 1004, 'humidity': 98, 'sea_level': 1004, 'grnd_level': 1000}, 'visibility': 131, 'wind': {'speed': 13.73, 'deg': 344, 'gust': 25.7}, 'snow': {'1h': 0.28}, 'clouds': {'all': 100}, 'dt': 1639963723, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 45 of Set 1 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73.8, 'feels_like': 74.03, 'temp_min': 73.8, 'temp_max': 73.8, 'pressure': 993, 'humidity': 67, 'sea_level': 993, 'grnd_level': 990}, 'visibility': 10000, 'wind': {'speed': 18.25, 'deg': 312, 'gust': 32.77}, 'clouds': {'all': 98}, 'dt': 1639963724, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1639932542, 'sunset': 1639989547}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 46 of Set 1 | kangaatsiaq
# {'coord': {'lon': -53.4641, 'lat': 68.3065}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.03, 'feels_like': 11.77, 'temp_min': 24.03, 'temp_max': 24.03, 'pressure': 1014, 'humidity': 79, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 14.09, 'deg': 71, 'gust': 21}, 'clouds': {'all': 100}, 'dt': 1639963724, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3422683, 'name': 'Kangaatsiaq', 'cod': 200}
# Processing Record 47 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 46.51, 'feels_like': 39.11, 'temp_min': 46.11, 'temp_max': 46.51, 'pressure': 1012, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1639963725, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1639901532, 'sunset': 1639962577}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 48 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 87.96, 'feels_like': 100.56, 'temp_min': 87.96, 'temp_max': 87.96, 'pressure': 1016, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 100}, 'clouds': {'all': 40}, 'dt': 1639963725, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1640019360, 'sunset': 1640067679}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 49 of Set 1 | clyde river
# {'coord': {'lon': -68.5914, 'lat': 70.4692}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 8.83, 'feels_like': -3.41, 'temp_min': 8.83, 'temp_max': 8.83, 'pressure': 1012, 'humidity': 92}, 'visibility': 9656, 'wind': {'speed': 8.05, 'deg': 340}, 'clouds': {'all': 100}, 'dt': 1639963725, 'sys': {'type': 1, 'id': 776, 'country': 'CA', 'sunrise': 0, 'sunset': 0}, 'timezone': -18000, 'id': 5924351, 'name': 'Clyde River', 'cod': 200}
# Processing Record 50 of Set 1 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 25.09, 'feels_like': 15.64, 'temp_min': 25.09, 'temp_max': 25.09, 'pressure': 1019, 'humidity': 74, 'sea_level': 1019, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 67, 'gust': 10}, 'clouds': {'all': 100}, 'dt': 1639963726, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 1 of Set 2 | sao felix do xingu
# {'coord': {'lon': -51.995, 'lat': -6.6447}, 'weather': [{'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 73.29, 'feels_like': 74.93, 'temp_min': 73.29, 'temp_max': 73.29, 'pressure': 1011, 'humidity': 98, 'sea_level': 1011, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 1.86, 'deg': 82, 'gust': 1.9}, 'rain': {'1h': 5.46}, 'clouds': {'all': 100}, 'dt': 1639963726, 'sys': {'country': 'BR', 'sunrise': 1639904999, 'sunset': 1639950025}, 'timezone': -10800, 'id': 3388847, 'name': 'São Félix do Xingu', 'cod': 200}
# Processing Record 2 of Set 2 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 74.07, 'feels_like': 75.22, 'temp_min': 74.07, 'temp_max': 74.07, 'pressure': 1013, 'humidity': 86, 'sea_level': 1013, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 12.64, 'deg': 16, 'gust': 15.75}, 'rain': {'1h': 1.61}, 'clouds': {'all': 100}, 'dt': 1639963726, 'sys': {'country': 'PF', 'sunrise': 1639923033, 'sunset': 1639971831}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 3 of Set 2 | tabuk
# {'coord': {'lon': 121.4443, 'lat': 17.4189}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 71.64, 'feels_like': 73.15, 'temp_min': 71.64, 'temp_max': 71.64, 'pressure': 1016, 'humidity': 99, 'sea_level': 1016, 'grnd_level': 995}, 'visibility': 3162, 'wind': {'speed': 5.14, 'deg': 295, 'gust': 11.27}, 'clouds': {'all': 100}, 'dt': 1639963177, 'sys': {'country': 'PH', 'sunrise': 1639952347, 'sunset': 1639992256}, 'timezone': 28800, 'id': 1684803, 'name': 'Tabuk', 'cod': 200}
# Processing Record 4 of Set 2 | lebu
# {'coord': {'lon': -73.65, 'lat': -37.6167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 56.97, 'feels_like': 56.73, 'temp_min': 56.97, 'temp_max': 56.97, 'pressure': 1015, 'humidity': 93, 'sea_level': 1015, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 15.61, 'deg': 189, 'gust': 28.16}, 'clouds': {'all': 24}, 'dt': 1639963727, 'sys': {'country': 'CL', 'sunrise': 1639906139, 'sunset': 1639959282}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# Processing Record 5 of Set 2 | shieli
# {'coord': {'lon': 66.75, 'lat': 44.1667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 41.05, 'feels_like': 35.91, 'temp_min': 41.05, 'temp_max': 41.05, 'pressure': 1019, 'humidity': 82, 'sea_level': 1019, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 7.94, 'deg': 197, 'gust': 13.42}, 'clouds': {'all': 100}, 'dt': 1639963727, 'sys': {'country': 'KZ', 'sunrise': 1639969475, 'sunset': 1640001390}, 'timezone': 18000, 'id': 1524801, 'name': 'Shīeli', 'cod': 200}
# Processing Record 6 of Set 2 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 70.05, 'feels_like': 71.04, 'temp_min': 70.05, 'temp_max': 70.05, 'pressure': 1012, 'humidity': 91, 'sea_level': 1012, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 6.64, 'deg': 201, 'gust': 9.57}, 'clouds': {'all': 100}, 'dt': 1639963727, 'sys': {'country': 'EC', 'sunrise': 1639914827, 'sunset': 1639958615}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 7 of Set 2 | geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.21, 'feels_like': 79.21, 'temp_min': 77.13, 'temp_max': 79.21, 'pressure': 1015, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 160}, 'clouds': {'all': 0}, 'dt': 1639963160, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1639948786, 'sunset': 1639999103}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 8 of Set 2 | severo-kurilsk
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 28.81, 'feels_like': 16.21, 'temp_min': 28.81, 'temp_max': 28.81, 'pressure': 1003, 'humidity': 80, 'sea_level': 1003, 'grnd_level': 1002}, 'visibility': 3516, 'wind': {'speed': 19.01, 'deg': 304, 'gust': 22.68}, 'snow': {'1h': 0.33}, 'clouds': {'all': 86}, 'dt': 1639963645, 'sys': {'country': 'RU', 'sunrise': 1639949639, 'sunset': 1639978311}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 9 of Set 2 | ust-omchug
# {'coord': {'lon': 149.6333, 'lat': 61.15}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -37.32, 'feels_like': -49.92, 'temp_min': -37.32, 'temp_max': -37.32, 'pressure': 1016, 'humidity': 98, 'sea_level': 1016, 'grnd_level': 931}, 'visibility': 10000, 'wind': {'speed': 3.38, 'deg': 35, 'gust': 3.24}, 'clouds': {'all': 97}, 'dt': 1639963728, 'sys': {'country': 'RU', 'sunrise': 1639955674, 'sunset': 1639975393}, 'timezone': 39600, 'id': 2120047, 'name': "Ust'-Omchug", 'cod': 200}
# Processing Record 10 of Set 2 | manggar
# {'coord': {'lon': 108.2667, 'lat': -2.8833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 80.83, 'feels_like': 85.69, 'temp_min': 80.83, 'temp_max': 80.83, 'pressure': 1012, 'humidity': 78, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 7307, 'wind': {'speed': 5.73, 'deg': 325, 'gust': 8.97}, 'rain': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1639963728, 'sys': {'country': 'ID', 'sunrise': 1639953347, 'sunset': 1639997583}, 'timezone': 25200, 'id': 1636426, 'name': 'Manggar', 'cod': 200}
# Processing Record 11 of Set 2 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 74.3, 'feels_like': 73.31, 'temp_min': 72.39, 'temp_max': 74.93, 'pressure': 1015, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 310}, 'rain': {'1h': 1.32}, 'clouds': {'all': 90}, 'dt': 1639963728, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1639932575, 'sunset': 1639971951}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 12 of Set 2 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.62, 'feels_like': 69.62, 'temp_min': 68.11, 'temp_max': 71.11, 'pressure': 1010, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 0, 'gust': 3}, 'clouds': {'all': 0}, 'dt': 1639963603, 'sys': {'type': 2, 'id': 2033665, 'country': 'ZA', 'sunrise': 1639971093, 'sunset': 1640022977}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 13 of Set 2 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.86, 'feels_like': 7.3, 'temp_min': 18.86, 'temp_max': 18.86, 'pressure': 1022, 'humidity': 72, 'sea_level': 1022, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 10.22, 'deg': 74, 'gust': 12.62}, 'clouds': {'all': 100}, 'dt': 1639963729, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 14 of Set 2 | kabinda
# {'coord': {'lon': 24.4833, 'lat': -6.1333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 65.73, 'feels_like': 66.42, 'temp_min': 65.73, 'temp_max': 65.73, 'pressure': 1010, 'humidity': 94, 'sea_level': 1010, 'grnd_level': 915}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 96, 'gust': 1.16}, 'clouds': {'all': 100}, 'dt': 1639963729, 'sys': {'country': 'CD', 'sunrise': 1639973120, 'sunset': 1640018039}, 'timezone': 7200, 'id': 215527, 'name': 'Kabinda', 'cod': 200}
# Processing Record 15 of Set 2 | ende
# {'coord': {'lon': 121.6623, 'lat': -8.8432}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.86, 'feels_like': 95.14, 'temp_min': 85.86, 'temp_max': 85.86, 'pressure': 1013, 'humidity': 71, 'sea_level': 1013, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 1.68, 'deg': 216, 'gust': 2.35}, 'clouds': {'all': 100}, 'dt': 1639963729, 'sys': {'country': 'ID', 'sunrise': 1639949501, 'sunset': 1639994997}, 'timezone': 28800, 'id': 1644932, 'name': 'Ende', 'cod': 200}
# Processing Record 16 of Set 2 | kushiro
# {'coord': {'lon': 144.3747, 'lat': 42.975}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 27.55, 'feels_like': 23.65, 'temp_min': 27.55, 'temp_max': 27.55, 'pressure': 1011, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 150}, 'clouds': {'all': 20}, 'dt': 1639963201, 'sys': {'type': 1, 'id': 7977, 'country': 'JP', 'sunrise': 1639950588, 'sunset': 1639983005}, 'timezone': 32400, 'id': 2129376, 'name': 'Kushiro', 'cod': 200}
# Processing Record 17 of Set 2 | mullaitivu
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E7DAC08>)
# Processing Record 18 of Set 2 | alice springs
# {'coord': {'lon': 133.8833, 'lat': -23.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 85.55, 'feels_like': 82.65, 'temp_min': 85.55, 'temp_max': 85.55, 'pressure': 1016, 'humidity': 23}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 100}, 'clouds': {'all': 0}, 'dt': 1639963165, 'sys': {'type': 1, 'id': 9483, 'country': 'AU', 'sunrise': 1639944841, 'sunset': 1639993788}, 'timezone': 34200, 'id': 2077895, 'name': 'Alice Springs', 'cod': 200}
# Processing Record 19 of Set 2 | diphu
# {'coord': {'lon': 93.4333, 'lat': 25.8333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 53.73, 'feels_like': 52.93, 'temp_min': 53.73, 'temp_max': 53.73, 'pressure': 1019, 'humidity': 88, 'sea_level': 1019, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 0.58, 'deg': 126, 'gust': 1.07}, 'clouds': {'all': 1}, 'dt': 1639963730, 'sys': {'country': 'IN', 'sunrise': 1639960086, 'sunset': 1639997966}, 'timezone': 19800, 'id': 1272525, 'name': 'Diphu', 'cod': 200}
# Processing Record 20 of Set 2 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.64, 'feels_like': 14.4, 'temp_min': 24.64, 'temp_max': 24.64, 'pressure': 1024, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1639963436, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 21 of Set 2 | quatre cocos
# {'coord': {'lon': 57.7625, 'lat': -20.2078}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.08, 'feels_like': 77.2, 'temp_min': 75.31, 'temp_max': 76.08, 'pressure': 1012, 'humidity': 81, 'sea_level': 1012, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 293, 'gust': 7.05}, 'clouds': {'all': 79}, 'dt': 1639963730, 'sys': {'type': 2, 'id': 2002134, 'country': 'MU', 'sunrise': 1639963552, 'sunset': 1640011628}, 'timezone': 14400, 'id': 1106643, 'name': 'Quatre Cocos', 'cod': 200}
# Processing Record 22 of Set 2 | tazovskiy
# {'coord': {'lon': 78.7, 'lat': 67.4667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -39.69, 'feels_like': -52.29, 'temp_min': -39.69, 'temp_max': -39.69, 'pressure': 1035, 'humidity': 99, 'sea_level': 1035, 'grnd_level': 1031}, 'visibility': 10000, 'wind': {'speed': 6.11, 'deg': 112, 'gust': 6.69}, 'clouds': {'all': 53}, 'dt': 1639963731, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 18000, 'id': 1489853, 'name': 'Tazovsky', 'cod': 200}
# Processing Record 23 of Set 2 | kalya
# {'coord': {'lon': 77.1806, 'lat': 12.9793}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 58.82, 'feels_like': 58.77, 'temp_min': 55.4, 'temp_max': 58.82, 'pressure': 1018, 'humidity': 93, 'sea_level': 1018, 'grnd_level': 915}, 'visibility': 10000, 'wind': {'speed': 6.4, 'deg': 81, 'gust': 11.27}, 'clouds': {'all': 41}, 'dt': 1639963732, 'sys': {'type': 1, 'id': 9205, 'country': 'IN', 'sunrise': 1639962480, 'sunset': 1640003376}, 'timezone': 19800, 'id': 1265591, 'name': 'Kalya', 'cod': 200}
# Processing Record 24 of Set 2 | talnakh
# {'coord': {'lon': 88.3972, 'lat': 69.4865}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -33.68, 'feels_like': -45.53, 'temp_min': -33.68, 'temp_max': -33.68, 'pressure': 1036, 'humidity': 95, 'sea_level': 1036, 'grnd_level': 1026}, 'visibility': 10000, 'wind': {'speed': 3.18, 'deg': 119, 'gust': 3.04}, 'clouds': {'all': 68}, 'dt': 1639963733, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# Processing Record 25 of Set 2 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 67.86, 'feels_like': 66.45, 'temp_min': 67.86, 'temp_max': 67.86, 'pressure': 995, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 290, 'gust': 32.21}, 'clouds': {'all': 75}, 'dt': 1639963727, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1639938467, 'sunset': 1639993706}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 26 of Set 2 | aviles
# {'coord': {'lon': -5.9248, 'lat': 43.5547}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 44.69, 'feels_like': 44.69, 'temp_min': 41.38, 'temp_max': 46.72, 'pressure': 1020, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 180, 'gust': 1.99}, 'clouds': {'all': 0}, 'dt': 1639963733, 'sys': {'type': 2, 'id': 2001020, 'country': 'ES', 'sunrise': 1639986793, 'sunset': 1640018967}, 'timezone': 3600, 'id': 3129135, 'name': 'Avilés', 'cod': 200}
# Processing Record 27 of Set 2 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.79, 'feels_like': 67.12, 'temp_min': 66.79, 'temp_max': 67.89, 'pressure': 1013, 'humidity': 84, 'sea_level': 1013, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 15.57, 'deg': 85, 'gust': 24.36}, 'clouds': {'all': 100}, 'dt': 1639963733, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1639970817, 'sunset': 1640022862}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 28 of Set 2 | ust-shonosha
# {'coord': {'lon': 41.343, 'lat': 61.1531}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 2.75, 'feels_like': -9.85, 'temp_min': 2.75, 'temp_max': 2.75, 'pressure': 1003, 'humidity': 93, 'sea_level': 1003, 'grnd_level': 990}, 'visibility': 1288, 'wind': {'speed': 10.22, 'deg': 24, 'gust': 25.93}, 'clouds': {'all': 100}, 'dt': 1639963734, 'sys': {'country': 'RU', 'sunrise': 1639981678, 'sunset': 1640001386}, 'timezone': 10800, 'id': 477958, 'name': "Ust'-Shonosha", 'cod': 200}
# Processing Record 29 of Set 2 | tiznit
# {'coord': {'lon': -9.5, 'lat': 29.5833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59.04, 'feels_like': 57.79, 'temp_min': 59.04, 'temp_max': 59.04, 'pressure': 1021, 'humidity': 67, 'sea_level': 1021, 'grnd_level': 955}, 'visibility': 10000, 'wind': {'speed': 10.09, 'deg': 133, 'gust': 14.7}, 'clouds': {'all': 4}, 'dt': 1639963734, 'sys': {'country': 'MA', 'sunrise': 1639985300, 'sunset': 1640022177}, 'timezone': 3600, 'id': 2527087, 'name': 'Tiznit Province', 'cod': 200}
# Processing Record 30 of Set 2 | lagoa
# {'coord': {'lon': -27.9833, 'lat': 39.05}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 58.41, 'feels_like': 57.7, 'temp_min': 58.41, 'temp_max': 58.41, 'pressure': 993, 'humidity': 80, 'sea_level': 993, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 26.8, 'deg': 278, 'gust': 26.33}, 'clouds': {'all': 100}, 'dt': 1639963734, 'sys': {'country': 'PT', 'sunrise': 1639991219, 'sunset': 1640025133}, 'timezone': -3600, 'id': 3372964, 'name': 'Lagoa', 'cod': 200}
# Processing Record 31 of Set 2 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 70.32, 'feels_like': 71.42, 'temp_min': 67.87, 'temp_max': 71.1, 'pressure': 1012, 'humidity': 93}, 'visibility': 8000, 'wind': {'speed': 5.01, 'deg': 181, 'gust': 11.99}, 'clouds': {'all': 20}, 'dt': 1639963471, 'sys': {'type': 2, 'id': 268283, 'country': 'AR', 'sunrise': 1639902206, 'sunset': 1639955489}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 32 of Set 2 | charters towers
# {'coord': {'lon': 146.2667, 'lat': -20.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 89.24, 'feels_like': 87.94, 'temp_min': 89.24, 'temp_max': 89.24, 'pressure': 1012, 'humidity': 34, 'sea_level': 1012, 'grnd_level': 977}, 'visibility': 10000, 'wind': {'speed': 9.42, 'deg': 87, 'gust': 11.27}, 'clouds': {'all': 92}, 'dt': 1639963735, 'sys': {'country': 'AU', 'sunrise': 1639942318, 'sunset': 1639990366}, 'timezone': 36000, 'id': 2171722, 'name': 'Charters Towers', 'cod': 200}
# Processing Record 33 of Set 2 | adwa
# ...
# Processing Record 37 of Set 15 | petawawa
# {'coord': {'lon': -77.3328, 'lat': 45.9001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 4.59, 'feels_like': -2.6, 'temp_min': 4.59, 'temp_max': 4.59, 'pressure': 1028, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 280}, 'clouds': {'all': 1}, 'dt': 1639963936, 'sys': {'type': 1, 'id': 961, 'country': 'CA', 'sunrise': 1639918020, 'sunset': 1639949169}, 'timezone': -18000, 'id': 6101607, 'name': 'Petawawa', 'cod': 200}
# Processing Record 38 of Set 15 | parkes
# {'coord': {'lon': 148.1833, 'lat': -33.1333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 78.73, 'feels_like': 78.73, 'temp_min': 78.73, 'temp_max': 78.73, 'pressure': 1014, 'humidity': 30, 'sea_level': 1014, 'grnd_level': 972}, 'visibility': 10000, 'wind': {'speed': 7.47, 'deg': 221, 'gust': 7.2}, 'clouds': {'all': 20}, 'dt': 1639963936, 'sys': {'country': 'AU', 'sunrise': 1639940068, 'sunset': 1639991696}, 'timezone': 39600, 'id': 2153778, 'name': 'Parkes', 'cod': 200}
# Processing Record 39 of Set 15 | ust-uda
# {'coord': {'lon': 103.0304, 'lat': 54.1742}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': -16.62, 'feels_like': -26.66, 'temp_min': -16.62, 'temp_max': -16.62, 'pressure': 1030, 'humidity': 97, 'sea_level': 1030, 'grnd_level': 971}, 'visibility': 10000, 'wind': {'speed': 3.38, 'deg': 15, 'gust': 4.09}, 'clouds': {'all': 9}, 'dt': 1639963937, 'sys': {'country': 'RU', 'sunrise': 1639963517, 'sunset': 1639989927}, 'timezone': 28800, 'id': 2013865, 'name': "Ust'-Uda", 'cod': 200}
# Processing Record 40 of Set 15 | ilhabela
# {'coord': {'lon': -45.3581, 'lat': -23.7781}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.01, 'feels_like': 71.71, 'temp_min': 71.01, 'temp_max': 71.01, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 6.35, 'deg': 53, 'gust': 8.77}, 'clouds': {'all': 72}, 'dt': 1639963678, 'sys': {'country': 'BR', 'sunrise': 1639901436, 'sunset': 1639950401}, 'timezone': -10800, 'id': 3461425, 'name': 'Ilhabela', 'cod': 200}
# Processing Record 41 of Set 15 | agadez
# {'coord': {'lon': 10.25, 'lat': 19.75}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 54.66, 'feels_like': 51.51, 'temp_min': 54.66, 'temp_max': 54.66, 'pressure': 1022, 'humidity': 36, 'sea_level': 1022, 'grnd_level': 963}, 'visibility': 10000, 'wind': {'speed': 9.57, 'deg': 38, 'gust': 10.56}, 'clouds': {'all': 0}, 'dt': 1639963937, 'sys': {'country': 'NE', 'sunrise': 1639979312, 'sunset': 1640018682}, 'timezone': 3600, 'id': 2448083, 'name': 'Agadez', 'cod': 200}
# Processing Record 42 of Set 15 | karratha
# {'coord': {'lon': 116.8463, 'lat': -20.7377}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 93.33, 'feels_like': 100.18, 'temp_min': 93.33, 'temp_max': 93.33, 'pressure': 1010, 'humidity': 48, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 23.11, 'deg': 58, 'gust': 30.2}, 'clouds': {'all': 7}, 'dt': 1639963938, 'sys': {'country': 'AU', 'sunrise': 1639949303, 'sunset': 1639997507}, 'timezone': 28800, 'id': 6620339, 'name': 'Karratha', 'cod': 200}
# Processing Record 43 of Set 15 | sharjah
# {'coord': {'lon': 55.4033, 'lat': 25.3573}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 63.59, 'feels_like': 63.46, 'temp_min': 59.16, 'temp_max': 67.98, 'pressure': 1018, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 120}, 'clouds': {'all': 0}, 'dt': 1639963938, 'sys': {'type': 1, 'id': 7545, 'country': 'AE', 'sunrise': 1639969156, 'sunset': 1640007157}, 'timezone': 14400, 'id': 292672, 'name': 'Sharjah city', 'cod': 200}
# Processing Record 44 of Set 15 | taunggyi
# {'coord': {'lon': 97.0333, 'lat': 20.7833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 57.79, 'temp_min': 59, 'temp_max': 59, 'pressure': 1018, 'humidity': 68, 'sea_level': 1018, 'grnd_level': 864}, 'visibility': 10000, 'wind': {'speed': 0.87, 'deg': 228, 'gust': 1.19}, 'clouds': {'all': 0}, 'dt': 1639963938, 'sys': {'country': 'MM', 'sunrise': 1639958599, 'sunset': 1639997725}, 'timezone': 23400, 'id': 1293960, 'name': 'Taunggyi', 'cod': 200}
# Processing Record 45 of Set 15 | moyale
# {'coord': {'lon': 39.0584, 'lat': 3.5167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 67.28, 'feels_like': 66.9, 'temp_min': 67.28, 'temp_max': 67.28, 'pressure': 1013, 'humidity': 68, 'sea_level': 1013, 'grnd_level': 895}, 'visibility': 10000, 'wind': {'speed': 5.17, 'deg': 44, 'gust': 5.3}, 'clouds': {'all': 99}, 'dt': 1639963939, 'sys': {'country': 'KE', 'sunrise': 1639970629, 'sunset': 1640013532}, 'timezone': 10800, 'id': 186180, 'name': 'Moyale', 'cod': 200}
# Processing Record 46 of Set 15 | sorvag
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E83D9C8>)
# Processing Record 47 of Set 15 | kasongo
# {'coord': {'lon': 26.6667, 'lat': -4.45}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 68.31, 'feels_like': 69.49, 'temp_min': 68.31, 'temp_max': 68.31, 'pressure': 1011, 'humidity': 99, 'sea_level': 1011, 'grnd_level': 936}, 'visibility': 10000, 'wind': {'speed': 3.53, 'deg': 34, 'gust': 11.14}, 'rain': {'1h': 0.95}, 'clouds': {'all': 100}, 'dt': 1639963939, 'sys': {'country': 'CD', 'sunrise': 1639972774, 'sunset': 1640017337}, 'timezone': 7200, 'id': 213940, 'name': 'Kasongo', 'cod': 200}
# Processing Record 48 of Set 15 | westport
# {'coord': {'lon': -73.3579, 'lat': 41.1415}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 29.19, 'feels_like': 24.84, 'temp_min': 26.04, 'temp_max': 32.99, 'pressure': 1022, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 314, 'gust': 11.99}, 'clouds': {'all': 1}, 'dt': 1639963939, 'sys': {'type': 2, 'id': 2011298, 'country': 'US', 'sunrise': 1639916067, 'sunset': 1639949214}, 'timezone': -18000, 'id': 4845585, 'name': 'Westport', 'cod': 200}
# Processing Record 49 of Set 15 | dzhusaly
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E839A08>)
# Processing Record 50 of Set 15 | sideropolis
# {'coord': {'lon': -49.4244, 'lat': -28.5978}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 63.25, 'feels_like': 63.59, 'temp_min': 63.25, 'temp_max': 63.25, 'pressure': 1015, 'humidity': 92, 'sea_level': 1015, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 3.11, 'deg': 5, 'gust': 4.85}, 'clouds': {'all': 0}, 'dt': 1639963940, 'sys': {'country': 'BR', 'sunrise': 1639901762, 'sunset': 1639952028}, 'timezone': -10800, 'id': 3447598, 'name': 'Siderópolis', 'cod': 200}
# Processing Record 1 of Set 16 | kasangulu
# {'coord': {'lon': 15.1708, 'lat': -4.5911}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.88, 'feels_like': 79.5, 'temp_min': 77.88, 'temp_max': 77.94, 'pressure': 1009, 'humidity': 88, 'sea_level': 1009, 'grnd_level': 965}, 'visibility': 10000, 'wind': {'speed': 1.3, 'deg': 155, 'gust': 1.45}, 'rain': {'1h': 0.23}, 'clouds': {'all': 100}, 'dt': 1639963940, 'sys': {'type': 1, 'id': 2297, 'country': 'CD', 'sunrise': 1639975519, 'sunset': 1640020112}, 'timezone': 3600, 'id': 2315057, 'name': 'Kasangulu', 'cod': 200}
# Processing Record 2 of Set 16 | acapulco
# {'coord': {'lon': -99.8901, 'lat': 16.8634}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 82.22, 'feels_like': 87.8, 'temp_min': 82.22, 'temp_max': 82.22, 'pressure': 1010, 'humidity': 74}, 'visibility': 8047, 'wind': {'speed': 9.22, 'deg': 280}, 'clouds': {'all': 75}, 'dt': 1639963714, 'sys': {'type': 1, 'id': 7103, 'country': 'MX', 'sunrise': 1639918993, 'sunset': 1639959028}, 'timezone': -21600, 'id': 3533462, 'name': 'Acapulco de Juárez', 'cod': 200}
# Processing Record 3 of Set 16 | chara
# {'coord': {'lon': 118.2631, 'lat': 56.9064}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -28.12, 'feels_like': -28.12, 'temp_min': -28.12, 'temp_max': -28.12, 'pressure': 1026, 'humidity': 82, 'sea_level': 1026, 'grnd_level': 929}, 'visibility': 10000, 'wind': {'speed': 2.73, 'deg': 345, 'gust': 3.33}, 'clouds': {'all': 88}, 'dt': 1639963941, 'sys': {'country': 'RU', 'sunrise': 1639960943, 'sunset': 1639985188}, 'timezone': 32400, 'id': 2025630, 'name': 'Chara', 'cod': 200}
# Processing Record 4 of Set 16 | aasiaat
# {'coord': {'lon': -52.8699, 'lat': 68.7098}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 26.49, 'feels_like': 13.89, 'temp_min': 26.49, 'temp_max': 26.49, 'pressure': 1015, 'humidity': 77, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 18.54, 'deg': 59, 'gust': 29.39}, 'clouds': {'all': 100}, 'dt': 1639963941, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3424901, 'name': 'Aasiaat', 'cod': 200}
# Processing Record 5 of Set 16 | norilsk
# {'coord': {'lon': 88.2027, 'lat': 69.3535}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -32.21, 'feels_like': -32.21, 'temp_min': -32.21, 'temp_max': -32.21, 'pressure': 1036, 'humidity': 95, 'sea_level': 1036, 'grnd_level': 1028}, 'visibility': 10000, 'wind': {'speed': 2.28, 'deg': 151, 'gust': 2.37}, 'clouds': {'all': 67}, 'dt': 1639963942, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1497337, 'name': "Noril'sk", 'cod': 200}
# Processing Record 6 of Set 16 | pulaski
# {'coord': {'lon': -92.3001, 'lat': 34.7668}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 34, 'feels_like': 31.59, 'temp_min': 30.2, 'temp_max': 36.82, 'pressure': 1027, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 170}, 'clouds': {'all': 1}, 'dt': 1639963942, 'sys': {'type': 2, 'id': 47703, 'country': 'US', 'sunrise': 1639919512, 'sunset': 1639954865}, 'timezone': -21600, 'id': 4127619, 'name': 'Pulaski', 'cod': 200}
# Processing Record 7 of Set 16 | samusu
# {'cod': '404', 'message': 'city not found'}
# City not found, skipping...
# (<class 'KeyError'>, KeyError('coord'), <traceback object at 0x000001D88E8339C8>)
# Processing Record 8 of Set 16 | tartus
# {'coord': {'lon': 35.8866, 'lat': 34.889}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 60.49, 'feels_like': 59.02, 'temp_min': 60.49, 'temp_max': 60.49, 'pressure': 1009, 'humidity': 59, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 22.93, 'deg': 201, 'gust': 31.21}, 'clouds': {'all': 49}, 'dt': 1639963942, 'sys': {'type': 2, 'id': 2004173, 'country': 'SY', 'sunrise': 1639975187, 'sunset': 1640010497}, 'timezone': 7200, 'id': 163345, 'name': 'Tartous', 'cod': 200}
# Processing Record 9 of Set 16 | xiongzhou
# {'coord': {'lon': 114.3, 'lat': 25.1167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.06, 'feels_like': 50.23, 'temp_min': 53.06, 'temp_max': 53.06, 'pressure': 1024, 'humidity': 46, 'sea_level': 1024, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.04, 'deg': 81, 'gust': 3.58}, 'clouds': {'all': 100}, 'dt': 1639963943, 'sys': {'country': 'CN', 'sunrise': 1639954985, 'sunset': 1639993048}, 'timezone': 28800, 'id': 1788402, 'name': 'Xiongzhou', 'cod': 200}
# Processing Record 10 of Set 16 | puerto leguizamo
# {'coord': {'lon': -74.7819, 'lat': -0.1934}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.29, 'feels_like': 78.53, 'temp_min': 77.29, 'temp_max': 77.29, 'pressure': 1009, 'humidity': 81, 'sea_level': 1009, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 1.86, 'deg': 75, 'gust': 1.95}, 'clouds': {'all': 100}, 'dt': 1639963943, 'sys': {'country': 'CO', 'sunrise': 1639911145, 'sunset': 1639954820}, 'timezone': -18000, 'id': 3671437, 'name': 'Caucayá', 'cod': 200}
# Processing Record 11 of Set 16 | yumen
# {'coord': {'lon': 97.2, 'lat': 40.2833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 27.84, 'feels_like': 17.11, 'temp_min': 27.84, 'temp_max': 27.84, 'pressure': 1024, 'humidity': 20, 'sea_level': 1024, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 12.95, 'deg': 267, 'gust': 21.83}, 'clouds': {'all': 0}, 'dt': 1639963943, 'sys': {'country': 'CN', 'sunrise': 1639961389, 'sunset': 1639994855}, 'timezone': 28800, 'id': 1528998, 'name': 'Yumen', 'cod': 200}
# Processing Record 12 of Set 16 | zaoyang
# {'coord': {'lon': 112.7542, 'lat': 32.1272}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.08, 'feels_like': 47.53, 'temp_min': 51.08, 'temp_max': 51.08, 'pressure': 1023, 'humidity': 35, 'sea_level': 1023, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.42, 'deg': 231, 'gust': 3.53}, 'clouds': {'all': 85}, 'dt': 1639963944, 'sys': {'country': 'CN', 'sunrise': 1639956311, 'sunset': 1639992464}, 'timezone': 28800, 'id': 1785462, 'name': 'Zaoyang', 'cod': 200}
# Processing Record 13 of Set 16 | sychevka
# {'coord': {'lon': 34.2736, 'lat': 55.8252}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.3, 'feels_like': 5.7, 'temp_min': 18.3, 'temp_max': 18.3, 'pressure': 994, 'humidity': 92, 'sea_level': 994, 'grnd_level': 970}, 'visibility': 737, 'wind': {'speed': 13.15, 'deg': 344, 'gust': 25.88}, 'clouds': {'all': 100}, 'dt': 1639963944, 'sys': {'country': 'RU', 'sunrise': 1639980654, 'sunset': 1640005805}, 'timezone': 10800, 'id': 485280, 'name': 'Sychëvka', 'cod': 200}
# Processing Record 14 of Set 16 | zapolyarnyy
# {'coord': {'lon': 30.8136, 'lat': 69.4154}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 24.08, 'feels_like': 12.96, 'temp_min': 24.08, 'temp_max': 24.08, 'pressure': 1022, 'humidity': 80, 'sea_level': 1022, 'grnd_level': 1003}, 'visibility': 5739, 'wind': {'speed': 11.72, 'deg': 19, 'gust': 22.79}, 'snow': {'1h': 0.14}, 'clouds': {'all': 100}, 'dt': 1639963944, 'sys': {'type': 1, 'id': 1639, 'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 10800, 'id': 464790, 'name': 'Zapolyarnyy', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)

# %%
# Create output file
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# export the city_data into a csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
city_data_df.tail(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 686           Aasiaat      GL  68.7098  -52.8699     26.49        77
# 687           Norilsk      RU  69.3535   88.2027    -32.21        95
# 688           Pulaski      US  34.7668  -92.3001     36.82        82
# 689            Tartus      SY  34.8890   35.8866     60.49        59
# 690         Xiongzhou      CN  25.1167  114.3000     53.06        46
# 691  Puerto Leguizamo      CO  -0.1934  -74.7819     77.29        81
# 692             Yumen      CN  40.2833   97.2000     27.84        20
# 693           Zaoyang      CN  32.1272  112.7542     51.08        35
# 694          Sychevka      RU  55.8252   34.2736     18.30        92
# 695       Zapolyarnyy      RU  69.4154   30.8136     24.08        80
#
#      Cloudiness  Wind Speed Current Description
# 686         100       18.54     overcast clouds
# 687          67        2.28       broken clouds
# 688           1        3.00           clear sky
# 689          49       22.93    scattered clouds
# 690         100        2.04     overcast clouds
# 691         100        1.86     overcast clouds
# 692           0       12.95           clear sky
# 693          85        2.42     overcast clouds
# 694         100       13.15     overcast clouds
# 695         100       11.72          light snow
